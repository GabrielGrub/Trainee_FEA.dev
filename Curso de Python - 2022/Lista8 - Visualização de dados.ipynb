# %% [markdown]
# # Lista 8 de exercícios - Visualização de dados

# %% [markdown]
# Chegamos à ultima lista de exercícios do nosso curso, do tema "Visualização de dados". Aqui, usaremos um *dataset* de dados de uma certa clínica médica, em que cada observação corresponde a um paciente. Importemos os dados:

# %%
# !pip install seaborn
# !pip install numpy
# !pip install pandas
# !pip install matplotlib.pyplot
# Out:
# Requirement already satisfied: seaborn in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.0.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\aeyam\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aeyam\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\aeyam\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (1.24.2)
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aeyam\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\aeyam\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.24.2)
# Requirement already satisfied: six>=1.5 in c:\users\aeyam\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importando as bibliotecas
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# baixando os dados #
data = pd.read_csv("insurance.csv")
display(data)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# Breve descrição das colunas:

# %% [markdown]
# **age**: idade do beneficiário primário
#
# **sex**: gênero do contratante
#
# **bmi**: índice de massa corporal (IMC)
#
# **children**: número de crianças cobertas pelo plano / número de dependentes
#
# **smoker**: fumante ("yes", se fumante; "no", se não fumante)
#
# **region**: área residencial do paciente nos EUA: Nordeste (northeast), Sudeste (southeast), Sudoeste (southwest), Noroeste (northwest).
#
# **charges**: custos médicos individuais cobrados pelo plano de saúde

# %% [markdown]
# Explorando os dados:

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# ## Exercícios:

# %% [markdown]
# ### 1) Faça um gráfico para analisar a associação entre idade e cobrança do plano.

# %%
### SEU CÓDIGO COMEÇA AQUI ###

# %% [markdown]
# ### 2)

# %% [markdown]
# #### a) Faça um gráfico para analisar a quantidade de fumantes e não-fumantes na amostra

# %%
plt.hist(x='smoker', data = data)
plt.xlabel("Fumante")
plt.ylabel("Frequência")
plt.title(" Frequencia de fumantes no plano de saúde")
plt.show()

# %% [markdown]
# #### b) Agora, faça um gráfico para analisar a quantidade de homens e mulheres na amostra

# %%
plt.hist(x='sex', data = data)
plt.xlabel("Gênero")
plt.ylabel("Frequência")
plt.title(" Freqência de Homens e Mulheres no plano de saúde")
plt.show()

# %% [markdown]
# #### c) Por fim, faça um gráfico para analisar a quantidade de indivíduos de cada sexo em cada categoria de "smoker" (fumante)
# dica: dê uma olhada na função ```.countplot()``` do *Seaborn*

# %%
### SEU CÓDIGO COMEÇA AQUI ###
import seaborn as sns

sns.countplot(x = 'smoker', data = data, hue = 'sex', hue_order={'male', 'female'})
plt.xlabel("Fumante")
plt.ylabel("Frequência")
plt.title("Gênero x Fumantes")
plt.show()

# %% [markdown]
# ### 3) Faça um gráfico que nos permita analisar a distribuição da cobrança do plano de saúde para cada região dos EUA

# %%
### SEU CÓDIGO COMEÇA AQUI ###
import matplotlib.pyplot as plt
sns.violinplot( x = 'region', data = data, y = 'charges')

plt.title("Distribuição da cobrança para cada região dos EUA")
plt.show()

# %% [markdown]
# ### 4) Faça um gráfico que nos permita ver a evolução da proporção de fumantes para cada idade na amostra

# %% [markdown]
# #### a) Faça um gráfico que nos permita ver a evolução da proporção de fumantes para cada idade na amostra

# %%
### SEU CÓDIGO COMEÇA AQUI ###

# %% [markdown]
# #### b) Faça um gráfico que nos permita ver a evolução do IMC médio para cada idade na amostra

# %%
### SEU CÓDIGO COMEÇA AQUI ###

# %% [markdown]
# #### c) Faça um gráfico que nos permita analisar a evolução do número médio de crianças no plano para cada idade na amostra

# %%
### SEU CÓDIGO COMEÇA AQUI ###

# %% [markdown]
# ### 5) Faça um gráfico que nos permita analisar a correlação entre todas as colunas ao mesmo tempo (para incluir "sex" e "smoker" na análise, crie variáveis binárias para cada uma das colunas)
# dica: crie um novo dataframe com as duas colunas citadas com variáveis binárias

# %%
### SEU CÓDIGO COMEÇA AQUI ###

# %% [markdown]
# ### 6) Faça um gráfico interativo e dinâmico da distribuição de cobrança para fumantes e não-fumantes
# dica: o nome da função na biblioteca é ```.box()```

# %%
### SEU CÓDIGO COMEÇA AQUI ###
