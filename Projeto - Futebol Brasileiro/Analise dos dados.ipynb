# %%
import pandas as pd

brasileirao = pd.read_csv("brasileirao.csv")
copa_do_brasil = pd.read_csv("copa_do_brasil.csv")
libertadores = pd.read_csv("copa_do_brasil.csv")

# %%
brasileirao.head()
# Out:
#               datetime       home_team home_team_state      away_team  \
# 0  2012-05-19 18:30:00    Palmeiras-SP              SP  Portuguesa-SP
# 1  2012-05-19 18:30:00        Sport-PE              PE    Flamengo-RJ
# 2  2012-05-19 21:00:00  Figueirense-SC              SC     Nautico-PE
# 3  2012-05-20 16:00:00  Ponte Preta-SP              SP    Atletico-MG
# 4  2012-05-20 16:00:00  Corinthians-SP              SP  Fluminense-RJ
#
#   away_team_state  home_goal  away_goal  season  round
# 0              SP        1.0        1.0    2012      1
# 1              RJ        1.0        1.0    2012      1
# 2              PE        2.0        1.0    2012      1
# 3              MG        0.0        1.0    2012      1
# 4              RJ        0.0        1.0    2012      1

# %%
copa_do_brasil.tail()
# Out:
#       round             datetime       home_team              away_team  \
# 1332      4  2021-08-04 21:30:00      Bahia - BA  Atlético Mineiro - MG
# 1333      4  2021-07-29 16:30:00  Fortaleza - CE               Crb - AL
# 1334      4  2021-08-05 16:00:00        Crb - AL         Fortaleza - CE
# 1335      4  2021-07-29 20:00:00   Flamengo - RJ               Abc - RN
# 1336      4  2021-08-05 21:30:00        Abc - RN          Flamengo - RJ
#
#       home_goal  away_goal  season
# 1332        NaN        NaN    2021
# 1333        NaN        NaN    2021
# 1334        NaN        NaN    2021
# 1335        NaN        NaN    2021
# 1336        NaN        NaN    2021

# %%
libertadores.tail()
# Out:
#       round             datetime       home_team              away_team  \
# 1332      4  2021-08-04 21:30:00      Bahia - BA  Atlético Mineiro - MG
# 1333      4  2021-07-29 16:30:00  Fortaleza - CE               Crb - AL
# 1334      4  2021-08-05 16:00:00        Crb - AL         Fortaleza - CE
# 1335      4  2021-07-29 20:00:00   Flamengo - RJ               Abc - RN
# 1336      4  2021-08-05 21:30:00        Abc - RN          Flamengo - RJ
#
#       home_goal  away_goal  season
# 1332        NaN        NaN    2021
# 1333        NaN        NaN    2021
# 1334        NaN        NaN    2021
# 1335        NaN        NaN    2021
# 1336        NaN        NaN    2021
